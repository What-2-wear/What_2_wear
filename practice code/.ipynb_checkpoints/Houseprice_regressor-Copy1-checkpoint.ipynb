# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np
#from sklearn.preprocessing import OneHotEncoder
#from sklearn.model_selection import cross_val_score
from  sklearn.model_selection import GridSearchCV, train_test_split
#from sklearn.metrics import classification_report
#from sklearn.ensemble import VotingClassifier, BaggingClassifier

# %%
df = pd.read_csv("../datasets/kc_house_data.csv")

# %%
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
# 5    101930     1.0           0     0  ...     11        3890           1530
# 6      6819     2.0           0     0  ...      7        1715              0
# 7      9711     1.0           0     0  ...      7        1060              0
# 8      7470     1.0           0     0  ...      7        1050            730
# 9      6560     2.0           0     0  ...      7        1890              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
# 5      2001             0    98053  47.6561 -122.005           4760
# 6      1995             0    98003  47.3097 -122.327           2238
# 7      1963             0    98198  47.4095 -122.315           1650
# 8      1960             0    98146  47.5123 -122.337           1780
# 9      2003             0    98038  47.3684 -122.031           2390
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
# 5      101930
# 6        6819
# 7        9711
# 8        8113
# 9        7570
#
# [10 rows x 21 columns]

# %%
df.corr()["price"].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
df['date']=  pd.to_datetime(df['date'])

# %%
df['date'] = df['date'].apply(lambda x: x.strftime('%Y%m%d'))
df["date"] = df["date"].astype(int)

# %% [markdown]
# # ###########특성공학부분#################
# ### 데이터의 수가 적으며 사용할 수 있는 모델이 제한되어있으므로 대부분은 사용하지 않았다

# %%
### df를 그냥 건드리긴 할껀데 일단 y값은 시각화를 위해 필요하다
X, y = df.drop("price", axis=1), df["price"]

# %%
#일단 얘를 Bool형으로 바꿔주자
#X["yr_renovated"].value_counts()

# %%
#X["yr_renovated"] = X["yr_renovated"] != 0

# %%
#X["yr_renovated"].value_counts()

# %%
#sns.barplot(X["yr_renovated"], y)

# %%
# 0아니면 8에 큰문제가 있다
#sns.barplot(X["bedrooms"], y)

# %%
#X["bedrooms"].value_counts()

# %%
# 그래프 패턴이 좀 이상하니 9 이상, 1이하를 모아주자
#X["bedrooms"][X["bedrooms"] > 7] =7
#X["bedrooms"][X["bedrooms"] < 1] =1

# %%
### 조금 더 봐줄만은하다
#sns.barplot(X["bedrooms"], y)

# %%
#X["lat"]

# %%
#X["lat"] = X["lat"]*100
#X["lat"] = X["lat"].astype(int)

# %%
#sns.displot(X["lat"])

# %%
#X["lat"][X["lat"] < 4720].value_counts()

# %%
#X["lat"][X["lat"] < 4720] =4720

# %%
#X["long"].value_counts()

# %%
#X["long"] = X["long"]*100
#X["long"] = X["long"].astype(int)

# %%
#sns.displot(X["long"])

# %%
#X["long"][X["long"] > -12170] = -12170
#X["long"][X["long"] < -12240] = -12240

# %%
#sns.displot(X["long"])

# %%
#sns.scatterplot(X["lat"], y)

# %%
#X["sqft_lot"].value_counts()

# %%
#sns.displot(X["sqft_lot"])

# %%
#X["sqft_lot"][X["sqft_lot"] > 30000] =30000

# %%
#sns.regplot(X["sqft_lot"], y)

# %%
#sns.displot(X["sqft_lot"])

# %%
X["temp"] = X["long"]+X["lat"]

# %% [markdown]
# # 이 아래는 모델단이므로 하나하나 보면서 실행할 수 있을것

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC, LinearRegression, SGDRegressor
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score, train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # 일단 수시로 돌리며 테스트해볼 코드를 만들어 둔다
# # 시간 단축을 위해 Train, test set으로 확인해보겠다

# %% [markdown]
# # 아랫단은 가장 마지막 테스트 코드이다

# %%
X_train
# Out:
#                id      date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 20408  2768200209  20141006         2       2.50         1500      1174
# 16186  4319200605  20140628         3       2.50         1700      9100
# 17468  7417700185  20150314         3       1.00         1020      8484
# 18530  7202330410  20150320         3       2.50         1470      3971
# 9088   8091411120  20140717         3       2.25         1400      7205
# ...           ...       ...       ...        ...          ...       ...
# 11147  2781250560  20141202         2       2.00         1200      3624
# 12936  1843100580  20140903         4       2.50         2340     13445
# 15598  3010300415  20150211         5       2.00         2280      5750
# 4392   7211402305  20150415         3       1.75         1780      5000
# 539    9485740340  20150310         4       2.50         1970      5106
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 20408     2.0           0     0          3  ...        1140            360
# 16186     1.0           0     0          3  ...        1160            540
# 17468     1.0           0     0          3  ...        1020              0
# 18530     2.0           0     0          3  ...        1470              0
# 9088      1.0           0     0          3  ...        1140            260
# ...       ...         ...   ...        ...  ...         ...            ...
# 11147     2.0           0     0          3  ...        1200              0
# 12936     2.0           0     0          3  ...        2340              0
# 15598     1.0           0     0          4  ...        1140           1140
# 4392      1.5           0     0          3  ...        1080            700
# 539       2.0           0     0          3  ...        1970              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 20408      2014             0    98107  47.6689 -122.363           1550
# 16186      1998             0    98126  47.5369 -122.378           1590
# 17468      1949             0    98155  47.7719 -122.310           1180
# 18530      2003             0    98053  47.6816 -122.035           1650
# 9088       1985             0    98030  47.3490 -122.166           1970
# ...         ...           ...      ...      ...      ...            ...
# 11147      2003             0    98038  47.3490 -122.025           1360
# 12936      1990             0    98042  47.3740 -122.125           2340
# 15598      1951             0    98116  47.5672 -122.390           1780
# 4392       1957             0    98146  47.5105 -122.360           1500
# 539        1999             0    98055  47.4490 -122.205           2230
#
#        sqft_lot15     temp
# 20408        1519 -74.6941
# 16186        8374 -74.8411
# 17468        9660 -74.5381
# 18530        3148 -74.3534
# 9088         7252 -74.8170
# ...           ...      ...
# 11147        2693 -74.6760
# 12936       11188 -74.7510
# 15598        5750 -74.8228
# 4392         5000 -74.8495
# 539          5109 -74.7560
#
# [17290 rows x 21 columns]

# %%
grad_boost = GradientBoostingRegressor(max_features= 5, max_depth= 7, learning_rate= 0.1)
grad_boost.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=7, max_features=5)

# %%
predicted = grad_boost.predict(X_test)
train_predicted = grad_boost.predict(X_train)
train_mse = mean_squared_error(y_train, train_predicted)
mse = mean_squared_error(y_test, predicted)
rmse = np.sqrt(mse)
train_rmse = np.sqrt(train_mse)
print(train_rmse, rmse)
# Out:
# 62546.1696645208 117379.93957755453

# %%
def displayscores(scores):
    print("Scores: ", scores)
    print("Mean: ", scores.mean())
    print("Standard deviation: ", scores.std())

# %%
scores = cross_val_score(model, X, y, scoring="neg_mean_squared_error", n_jobs = -1, cv=10)
displayscores(np.sqrt(-scores))
# Out:
# Scores:  [114022.7162509  132620.55813149 108507.20985647 131372.3059305
#  101706.18733172 114109.55016952 120826.17654016 109242.28706455
#  113260.15913758 131391.05202453]
# Mean:  117705.82024374332
# Standard deviation:  10318.627941680315

# %%
model = GradientBoostingRegressor()

param_grid = {
    'learning_rate':[0.008, 0.01, 0.05, 0.1],
    'max_depth':[3, 5, 7, 10, 20, 30],
    'max_features': np.arange(3, 7)    
}

clf = RandomizedSearchCV(model, param_grid,n_iter=10,cv=3, scoring='neg_mean_squared_error',      verbose=1,    n_jobs=-1
)

# %%
clf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=GradientBoostingRegressor(), n_jobs=-1,
#                    param_distributions={'learning_rate': [0.008, 0.01, 0.05,
#                                                           0.1],
#                                         'max_depth': [3, 5, 7, 10, 20, 30],
#                                         'max_features': array([3, 4, 5, 6])},
#                    scoring='neg_mean_squared_error', verbose=1)

# %%
clf.best_params_
# Out:
# {'max_features': 6, 'max_depth': 20, 'learning_rate': 0.1}
